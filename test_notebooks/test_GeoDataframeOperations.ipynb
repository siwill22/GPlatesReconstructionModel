# %%
# %load_ext autoreload
# %autoreload 2

from gprm.datasets import Rocks, Reconstructions

deposits = Rocks.BaseMetalDeposits(deposit_type='Cu-por')

deposits.plot()
# Out:
# <AxesSubplot:>

# %%
M2021 = Reconstructions.fetch_Merdith2021()

deposits_M2021 = M2021.assign_plate_ids(deposits)

deposits_M2021

# %%
deposits_M2021_50Ma = M2021.reconstruct(deposits_M2021, 50.)

deposits_M2021_50Ma
