# %% [markdown]
# ## PlateTree class usage examples

# %%
import pygplates

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

print(pygplates.__version__)

from gprm import ReconstructionModel, PlateTree
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2.2.0.28

# %%
M2016 = ReconstructionModel('Muller++2016')
#M2016.from_web_service('MULLER2016')
M2016.add_rotation_model('/Applications/GPlates-2.2.0/SampleData/FeatureCollections/Rotations/Matthews_etal_GPC_2016_410-0Ma_GK07.rot')
M2016.add_static_polygons('/Applications/GPlates-2.2.0/SampleData/FeatureCollections/StaticPolygons/Muller_etal_AREPS_2016_StaticPolygons.gpmlz')

# %%
tree_object = PlateTree(M2016)

tree_object.plot_snapshot(200.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b9c841824856> in <module>
#       6  chains,
#       7  reconstruction_tree,
# ----> 8  reconstructed_polygons) = tree_snapshot(M2016.static_polygons,
#       9                                              M2016.rotation_model,
#      10                                              190.)
#
# NameError: name 'tree_snapshot' is not defined
